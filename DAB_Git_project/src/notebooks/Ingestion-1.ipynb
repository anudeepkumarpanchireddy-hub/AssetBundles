# %%
dbutils.widgets.text("catalag_name", "uber")
dbutils.widgets.text("schema_name", "bronze")

# %%
df = spark.read.table("uber.bronze.bulk_rides")
df.display()

# %%
df1 = df.select("ride_id", "passenger_id", "passenger_name", "passenger_email", "passenger_phone")

# %%
df1.write.mode("overwrite").saveAsTable("dev.default.rider_details")
