# %%
df = spark.read.table("uber.bronze.bulk_rides")

# %%
df1 = df.select("ride_id", "vehicle_id", "vehicle_type_id", "vehicle_make_id", "vehicle_model")

# %%
df1.write.mode("overwrite").saveAsTable("dev.default.vehicle_details")
